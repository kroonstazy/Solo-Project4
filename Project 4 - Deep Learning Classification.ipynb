# %%
#라이브러리 불러오기
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

np.random.seed(63)

# %%
# DataSet 불러오기 레드와인 데이터
red = pd.read_csv('winequality-red.csv', sep=';') # comma 대신 semi colon으로 데이터가 구분되어있다.
white = pd.read_csv('winequality-white.csv', sep=';')

# %%
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red['kind']= 1
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
white['kind']=0
white
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
target = 'quality'
target_class = 'kind'
features = red.columns.drop([target, target_class])

# %%
train_all, val_all = train_test_split(all_wine, test_size=0.1, random_state=63)

train_all, test_all = train_test_split(train_all, test_size=0.25, random_state=63)

# %%
X_train_all = train_all[features]
y_train_all = train_all[target]
y_train_k_all = train_all[target_class]

X_val_all = val_all[features]
y_val_all = val_all[target]
y_val_k_all = val_all[target_class]

X_test_all = test_all[features]
y_test_all = test_all[target]
y_test_k_all = test_all[target_class]

X_train_all.shape, y_train_all.shape, y_train_k_all.shape, X_val_all.shape, y_val_all.shape, y_val_k_all.shape, X_test_all.shape, y_test_all.shape, y_test_all.shape
# Out:
# ((3897, 11),
#  (3897,),
#  (3897,),
#  (1300, 11),
#  (1300,),
#  (1300,),
#  (1300, 11),
#  (1300,),
#  (1300,))

# %% [markdown]
# #### Baseline (If all Guess as Red, 32% change of being right.)

# %%
1599/4898
# Out:
# 0.32645977950183747

# %% [markdown]
# # Classification - Red Wine or White Wine

# %%
all_wine = pd.concat([red, white])
all_wine.reset_index(drop=True)
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ## Random Forest Classifier - Red or White

# %%
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

#파이프라인
pipe = make_pipeline(
    RandomForestClassifier(n_jobs=-1,
                          oob_score=True,
                          random_state=63,
                          max_depth = 50,
                          )
)

#훈련
pipe.fit(X_train_all, y_train_k_all)

#예측
y_pred_all = pipe.predict(X_val_all)

#정확도
print('훈련 정확도 : ',pipe.score(X_train_all, y_train_k_all))
print('검증 정확도 (model.score): ',pipe.score(X_val_all, y_val_k_all))
print('Test 정확도 (model.score): ',pipe.score(X_test_all, y_test_k_all))
print('Out Of Bag 을 사용한 검증 정확도 : ',pipe.named_steps['randomforestclassifier'].oob_score_)
print('훈련-검증 차이', pipe.score(X_train_all, y_train_k_all) - pipe.score(X_val_all, y_val_k_all))
print('---')
print('Classification Report For Train \n', classification_report(y_test_k_all, y_pred_all)) #훈련
# Out:
# 훈련 정확도 :  0.9997433923530922
# 검증 정확도 (model.score):  0.9907692307692307
# Test 정확도 (model.score):  0.9953846153846154
# Out Of Bag 을 사용한 검증 정확도 :  0.9953810623556582
# 훈련-검증 차이 0.00897416158386144
# ---
# Classification Report For Train
#                precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77      1005
#            1       0.23      0.25      0.24       295
#
#     accuracy                           0.64      1300
#    macro avg       0.50      0.50      0.50      1300
# weighted avg       0.65      0.64      0.65      1300

# %%
import tensorflow as tf
from tensorflow.keras.layers import Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential

tf.random.set_seed(63)

# %%
model_classification = Sequential([
    Dense(64, activation='relu', input_dim=11),
    Dense(128, activation='relu'),
    Dense(256, activation='relu'),
    Dropout(0.1),
    Dense(128, activation='relu'),
    Dense(64, activation='relu'),
    Dense(1, activation='sigmoid'),
])

model_classification.compile(optimizer='adam', loss='binary_crossentropy', metrics=['acc'])

# %%
model_classification.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 64)                768
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 65
# ...

# %%
early_stop = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=10, verbose=1)

hist = model_classification.fit(X_train_all, y_train_k_all,
                                epochs=75,
                               verbose=1,
                               validation_data=(X_val_all, y_val_k_all),
                               callbacks=[early_stop])
# Out:
# Epoch 1/75
# 122/122 [==============================] - 1s 2ms/step - loss: 0.4845 - acc: 0.8524 - val_loss: 0.2111 - val_acc: 0.9308
# Epoch 2/75
# 122/122 [==============================] - 0s 909us/step - loss: 0.2261 - acc: 0.9247 - val_loss: 0.1915 - val_acc: 0.9308
# Epoch 3/75
# 122/122 [==============================] - 0s 920us/step - loss: 0.1925 - acc: 0.9355 - val_loss: 0.2169 - val_acc: 0.9192
# Epoch 4/75
# 122/122 [==============================] - 0s 926us/step - loss: 0.1660 - acc: 0.9456 - val_loss: 0.1648 - val_acc: 0.9408
# Epoch 5/75
# 122/122 [==============================] - 0s 900us/step - loss: 0.1745 - acc: 0.9423 - val_loss: 0.1556 - val_acc: 0.9438
# Epoch 6/75
# 122/122 [==============================] - 0s 896us/step - loss: 0.1509 - acc: 0.9439 - val_loss: 0.1776 - val_acc: 0.9446
# Epoch 7/75
# 122/122 [==============================] - 0s 917us/step - loss: 0.1533 - acc: 0.9464 - val_loss: 0.1997 - val_acc: 0.9308
# Epoch 8/75
# ...

# %% [markdown]
# Validation Loss를 기준으로 가장 성능이 좋았던 모델은
#
# Epoch 44 : loss: 0.0582 - acc: 0.9820 - val_loss: 0.0601 - val_acc: 0.9831
# 훈련 정확도: 0.982, 검증 정확도:0.9831
